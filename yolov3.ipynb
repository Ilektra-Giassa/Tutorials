# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilektra-Giassa/Tutorials/blob/main/yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # You Only Look Once v3

# %% [markdown]
# Setup

# %%
# !git clone https://github.com/ultralytics/yolov3  # clone
# %cd yolov3
# %pip install -qr requirements.txt  # install

import torch
from yolov3 import utils
display = utils.notebook_init()  # checks
# Out:
# Setup complete ✅

# %%
# !python detect.py --weights yolov3.pt --img 640 --conf 0.25 --source data/images
display.Image(filename='runs/detect/exp/bus.jpg', width=600)
# Out:
# ...
# detect: weights=['yolov3.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-22-g0bbd055 torch 1.12.1+cu113 CPU
#
# ...
# 100% 119M/119M [00:11<00:00, 10.8MB/s]
#
# Fusing layers...
# Model Summary: 261 layers, 61922845 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bicycle, 1 bus, Done. (2.380s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (1.844s)
# Speed: 3.0ms pre-process, 2112.3ms inference, 14.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
