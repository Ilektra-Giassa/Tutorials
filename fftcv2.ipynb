# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilektra-Giassa/Tutorials/blob/main/fftcv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FFT and DFT

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy import fft

# %%
#display image - cv2.imshow does not work on colab
from google.colab.patches import cv2_imshow
from skimage import io
img_path='/content/xfiles.jpg'
image = io.imread(img_path)
cv2_imshow(image)
image.shape # (139, 250, 3)
# Out:
# <PIL.Image.Image image mode=RGB size=250x139 at 0x7F771ED130D0>
# (139, 250, 3)
